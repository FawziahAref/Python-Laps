# %%
print('Welcome to Python Programming!')
# Out:
# Welcome to Python Programming!

# %%
name='Fawziah Aref'
print(name)
#Fawziah
# Out:
# Fawziah Aref

# %%
Claasname='Advanced programming'
print(Claasname)
# Out:
# Advanced programming

# %%
"""
welcome
"""
# Out:
# '\nwelcome\n'

# %%
student_name="Alice"
print(type(student_name))
# Out:
# <class 'str'>

# %%
age=20
print(type(age))
# Out:
# <class 'int'>

# %%
gpa=3.75
print(type(gpa))
# Out:
# <class 'float'>

# %%
subjects=["Math", "Python", "Physics"] 
print(type(subjects))
# Out:
# <class 'list'>

# %%
student_info={"id": 101, "year": 2}
print(type(student_info ))
# Out:
# <class 'dict'>

# %%
skills={"Python", "SQL"} 
print(type(skills))
# Out:
# <class 'set'>

# %%
is_enrolled=True  
print(type(is_enrolled ))
# Out:
# <class 'bool'>

# %%
graduation_date=None  
print(type(graduation_date))
# Out:
# <class 'NoneType'>
